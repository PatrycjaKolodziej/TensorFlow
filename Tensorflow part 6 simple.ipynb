# %% [markdown]
# # Tensorflow - Linear & Logistic regression - Sixth Exercise (25 minutes)
# @author Tomasz Skrzypczyk

# %% [markdown]
# **Remember Linear and Logistic regression?**
#
#
#
# Did you know that those two models can be expressed as a single neuron neural network?
#
#
#
#
# To create a **Linear Regression** model create a model with one `Dense` layer and set the `units` parametr to `1`. That's it!
#
#
#
#
#
#
# To create a **Logistic Regression** model create the same model but set another parameter - `activation = "sigmoid"`.

# %% [markdown]
# # Linear Regression

# %%
import tensorflow as tf
import pandas as pd
from sklearn.metrics import r2_score

# create fake dataset for regression using random tensors we used in the first exercise
# make it a 100 samples for training, 30 for validation and 30 for testing,
# a sample should contain 5 features - X_train (100, 5), X_val, X_test (30,5)

X_train = tf.random.normal((100,5))
X_val = tf.random.normal((30,5))
X_test = tf.random.normal((30,5))

y_train = tf.random.normal((100,1))
y_val = tf.random.normal((30,1))
y_test = tf.random.normal((30,1))

# define your LinearRegression model as a Sequential model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_shape=(5,)))

model.compile(loss="mse", metrics=["mae"], optimizer="sgd")

# train it ... 
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# ... and evaluate,
model.evaluate(X_test, y_test)

# now plot the training curves
df = pd.DataFrame(history.history).plot()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 52ms/step - loss: 1.6870 - mae: 1.0535 - val_loss: 1.2007 - val_mae: 0.9029
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.5628 - mae: 1.0191 - val_loss: 1.0778 - val_mae: 0.8488
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1.4369 - mae: 0.9819 - val_loss: 0.9792 - val_mae: 0.7995
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.3390 - mae: 0.9491 - val_loss: 0.9269 - val_mae: 0.7798
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.2862 - mae: 0.9312 - val_loss: 0.8869 - val_mae: 0.7585
# Epoch 6/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.2387 - mae: 0.9125 - val_loss: 0.8113 - val_mae: 0.7078
# Epoch 7/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1487 - mae: 0.8826 - val_loss: 0.7868 - val_mae: 0.6905
# Epoch 8/100
# ...

# %% [markdown]
# # Logistic regression

# %%
from keras.engine.training import input_layer_module
# create fake dataset for classification using random tensors we used in the first exercise
# make it a 100 samples for training, 30 for validation and 30 for testing
# a sample should contain 5 features and a label = 1 (tf.ones) - it's just a number, make it random with mean=2 and stddev = 4

X_train = tf.random.normal((100,5))
X_val = tf.random.normal((30,5))
X_test = tf.random.normal((30,5))

y_train = tf.ones((100,1))
y_val = tf.ones((30,1))
y_test = tf.ones((30,1))

# define your LinearRegression model as a Sequential model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1, input_shape=(5,), activation="sigmoid"))

model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")

# train it ... 
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# ... and evaluate,
model.evaluate(X_test, y_test)

# now plot the training curves
df = pd.DataFrame(history.history).plot()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py:1176: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# 4/4 [==============================] - 2s 179ms/step - loss: 0.0000e+00 - accuracy: 0.4500 - val_loss: 0.0000e+00 - val_accuracy: 0.6333
# Epoch 2/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0000e+00 - accuracy: 0.4500 - val_loss: 0.0000e+00 - val_accuracy: 0.6333
# Epoch 3/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - accuracy: 0.4500 - val_loss: 0.0000e+00 - val_accuracy: 0.6333
# Epoch 4/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0000e+00 - accuracy: 0.4500 - val_loss: 0.0000e+00 - val_accuracy: 0.6333
# Epoch 5/100
# ...
